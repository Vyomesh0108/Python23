# %%
import pandas as pd

data = pd.read_csv('IMDb movies.csv')
data
# Out:
# /var/folders/6m/tlc_3szx4psf8_dwhx0h93j80000gn/T/ipykernel_2575/1559817165.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('IMDb movies.csv')
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# ...

# %%
# first 5 rows
data.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
# last 3 rows
data.tail(3)
# Out:
#       imdb_title_id                       title              original_title  \
# 85852     tt9911774   Padmavyuhathile Abhimanyu   Padmavyuhathile Abhimanyu
# 85853     tt9914286           Sokagin Çocuklari           Sokagin Çocuklari
# 85854     tt9914942  La vida sense la Sara Amat  La vida sense la Sara Amat
#
#        year date_published          genre  duration country   language  \
# 85852  2019     2019-03-08          Drama       130   India  Malayalam
# 85853  2019     2019-03-15  Drama, Family        98  Turkey    Turkish
# 85854  2019     2020-02-05          Drama        74   Spain    Catalan
#
#                 director  ...  \
# 85852    Vineesh Aaradya  ...
# 85853  Ahmet Faik Akinci  ...
# 85854          Laura Jou  ...
#
#                                                   actors  \
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
# ...

# %%
# Statistics
data.describe()
# Out:
#            duration      avg_vote         votes     metascore  \
# count  85855.000000  85855.000000  8.585500e+04  13305.000000
# mean     100.351418      5.898656  9.493490e+03     55.896881
# std       22.553848      1.234987  5.357436e+04     17.784874
# min       41.000000      1.000000  9.900000e+01      1.000000
# 25%       88.000000      5.200000  2.050000e+02     43.000000
# 50%       96.000000      6.100000  4.840000e+02     57.000000
# 75%      108.000000      6.800000  1.766500e+03     69.000000
# max      808.000000      9.900000  2.278845e+06    100.000000
#
#        reviews_from_users  reviews_from_critics
# count        78258.000000          74058.000000
# mean            46.040826             27.479989
# std            178.511411             58.339158
# min              1.000000              1.000000
# 25%              4.000000              3.000000
# 50%              9.000000              8.000000
# 75%             27.000000             23.000000
# ...

# %%
# Data Types of Each Column
print("Data Types of Each Column")
data.dtypes
# Out:
# Data Types of Each Column
# imdb_title_id             object
# title                     object
# original_title            object
# year                      object
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
# How many columns and rows in your data
print("Number of Columns: ",len(data.columns))
print("Number of Rows: ",len(data))
# Out:
# Number of Columns:  22
# Number of Rows:  85855

# %%
# Number of missing values for each columns
print("Number of Missing Values for each columns")
data.isnull().sum()
# Out:
# Number of Missing Values for each columns
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     64
# language                   833
# director                    87
# writer                    1572
# production_company        4455
# actors                      69
# description               2115
# avg_vote                     0
# votes                        0
# budget                   62145
# usa_gross_income         70529
# worlwide_gross_income    54839
# metascore                72550
# reviews_from_users        7597
# reviews_from_critics     11797
# dtype: int64

# %%
# Delete Particular Columns
deleting_columns = ['imdb_title_id', 'original_title', 'usa_gross_income', 'worlwide_gross_income', 
                    'reviews_from_critics', 'metascore', 'actors', 'reviews_from_users']

newColumns = data.drop(columns = deleting_columns)
newColumns
# Out:
#                                 title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
# Setting English as a Missing Value for Language
newColumn['language'].fillna('English', inplace=True)
newColumn.head()
# Out:
#                      title  year date_published                     genre  \
# 84686  A Wakefield Project  2019     2021-05-07  Horror, Sci-Fi, Thriller
# 81909      Shadows in Mind  2019     2021-04-30                  Thriller
# 83083           Winterskin  2018     2021-04-16   Action, Fantasy, Horror
# 77295     The Terrible Two  2018     2021-04-02          Horror, Thriller
# 52656           The Father  2020     2021-01-08                     Drama
#
#        duration      country language        director  \
# 84686        88  Canada, USA  English      L.A. Lopes
# 81909        92          USA  English     Mark Schwab
# 83083        84           UK  English  Charlie Steeds
# 77295        84          USA  English     Billy Lewis
# 52656        97   UK, France  English  Florian Zeller
#
#                                     writer           production_company  \
# 84686                         Lindsay Seim         Ladywood Productions
# ...

# %%
# Setting $2000 as a Missing Value for Budget Column
newColumn['budget'].fillna(f"$ {'2000'}", inplace=True)
newColumn.head()
# Out:
#                          title  year date_published  \
# 0                   Miss Jerry  1894     1894-10-09
# 1  The Story of the Kelly Gang  1906     1906-12-26
# 2               Den sorte drøm  1911     1911-08-19
# 3                    Cleopatra  1912     1912-11-13
# 4                    L'Inferno  1911     1911-03-06
#
#                        genre  duration           country language  \
# 0                    Romance        45               USA     None
# 1    Biography, Crime, Drama        70         Australia     None
# 2                      Drama        53  Germany, Denmark      NaN
# 3             Drama, History       100               USA  English
# 4  Adventure, Drama, Fantasy        68             Italy  Italian
#
#                               director                                 writer  \
# 0                      Alexander Black                        Alexander Black
# 1                         Charles Tait                           Charles Tait
# ...

# %%
newColumn.sort_values(by = 'date_published', ascending = False, inplace = True)
newColumn.head()
# Out:
#                      title           year date_published  \
# 83917        Bad Education  TV Movie 2019  TV Movie 2019
# 84686  A Wakefield Project           2019     2021-05-07
# 81909      Shadows in Mind           2019     2021-04-30
# 83083           Winterskin           2018     2021-04-16
# 77295     The Terrible Two           2018     2021-04-02
#
#                           genre  duration      country language  \
# 83917  Biography, Comedy, Crime       108          USA  English
# 84686  Horror, Sci-Fi, Thriller        88  Canada, USA  English
# 81909                  Thriller        92          USA  English
# 83083   Action, Fantasy, Horror        84           UK  English
# 77295          Horror, Thriller        84          USA  English
#
#              director                        writer  \
# 83917     Cory Finley  Mike Makowsky, Robert Kolker
# 84686      L.A. Lopes                  Lindsay Seim
# 81909     Mark Schwab                   Mark Schwab
# ...

# %%
# Drop Row
newColumn.drop(83917, inplace=True)
newColumn
# Out:
#                              title  year date_published  \
# 84686          A Wakefield Project  2019     2021-05-07
# 81909              Shadows in Mind  2019     2021-04-30
# 83083                   Winterskin  2018     2021-04-16
# 77295             The Terrible Two  2018     2021-04-02
# 52656                   The Father  2020     2021-01-08
# ...                            ...   ...            ...
# 2                   Den sorte drøm  1911     1911-08-19
# 4                        L'Inferno  1911     1911-03-06
# 39150                  Karadjordje  1911           1911
# 1      The Story of the Kelly Gang  1906     1906-12-26
# 0                       Miss Jerry  1894     1894-10-09
#
#                            genre  duration           country language  \
# 84686   Horror, Sci-Fi, Thriller        88       Canada, USA  English
# 81909                   Thriller        92               USA  English
# 83083    Action, Fantasy, Horror        84                UK  English
# ...

# %%
newColumn.dropna(inplace=True)
newColumn
# Out:
#                              title  year date_published  \
# 84686          A Wakefield Project  2019     2021-05-07
# 81909              Shadows in Mind  2019     2021-04-30
# 83083                   Winterskin  2018     2021-04-16
# 77295             The Terrible Two  2018     2021-04-02
# 52656                   The Father  2020     2021-01-08
# ...                            ...   ...            ...
# 3                        Cleopatra  1912     1912-11-13
# 9                      Richard III  1912     1912-10-15
# 4                        L'Inferno  1911     1911-03-06
# 1      The Story of the Kelly Gang  1906     1906-12-26
# 0                       Miss Jerry  1894     1894-10-09
#
#                            genre  duration      country language  \
# 84686   Horror, Sci-Fi, Thriller        88  Canada, USA  English
# 81909                   Thriller        92          USA  English
# 83083    Action, Fantasy, Horror        84           UK  English
# ...

# %%
newColumn.dtypes
# Out:
# title                  object
# year                   object
# date_published         object
# genre                  object
# duration                int64
# country                object
# language               object
# director               object
# writer                 object
# production_company     object
# description            object
# avg_vote              float64
# votes                   int64
# budget                 object
# dtype: object

# %%
newColumn = newColumn.astype({'title': 'object',
                             'year': 'int64',
                             'date_published': 'object',
                             'genre': 'object',
                             'duration': 'int64',
                             'country': 'object',
                             'language': 'object',
                             'director': 'object', 
                             'writer': 'object',
                             'production_company': 'object',
                             'description': 'object',
                             'avg_vote': 'float64',
                             'votes': 'int64',
                             'budget': 'object'})

# %%
newColumn.dtypes
# Out:
# title                  object
# year                    int64
# date_published         object
# genre                  object
# duration                int64
# country                object
# language               object
# director               object
# writer                 object
# production_company     object
# description            object
# avg_vote              float64
# votes                   int64
# budget                 object
# dtype: object

# %%
print(newColumn['budget'].max())
# Out:
# ZAR 8400000

# %%
newColumn['date_published'] = pd.to_datetime(newColumn['date_published'], format = '%Y-%m-%d')

# %%
newColumn.dtypes
# Out:
# title                         object
# year                           int64
# date_published        datetime64[ns]
# genre                         object
# duration                       int64
# country                       object
# language                      object
# director                      object
# writer                        object
# production_company            object
# description                   object
# avg_vote                     float64
# votes                          int64
# budget                        object
# dtype: object

# %%
newColumn
# Out:
#                              title  year date_published  \
# 84686          A Wakefield Project  2019     2021-05-07
# 81909              Shadows in Mind  2019     2021-04-30
# 83083                   Winterskin  2018     2021-04-16
# 77295             The Terrible Two  2018     2021-04-02
# 52656                   The Father  2020     2021-01-08
# ...                            ...   ...            ...
# 3                        Cleopatra  1912     1912-11-13
# 9                      Richard III  1912     1912-10-15
# 4                        L'Inferno  1911     1911-03-06
# 1      The Story of the Kelly Gang  1906     1906-12-26
# 0                       Miss Jerry  1894     1894-10-09
#
#                            genre  duration      country language  \
# 84686   Horror, Sci-Fi, Thriller        88  Canada, USA  English
# 81909                   Thriller        92          USA  English
# 83083    Action, Fantasy, Horror        84           UK  English
# ...

# %%
newColumn[['title', 'production_company','year']].groupby('year').head()
# Out:
#                              title             production_company  year
# 84686          A Wakefield Project           Ladywood Productions  2019
# 81909              Shadows in Mind     Diamond in the Rough Films  2019
# 83083                   Winterskin    Dark Temple Motion Pictures  2018
# 77295             The Terrible Two                Orange St Films  2018
# 52656                   The Father                Trademark Films  2020
# ...                            ...                            ...   ...
# 3                        Cleopatra  Helen Gardner Picture Players  1912
# 9                      Richard III                  Le Film d'Art  1912
# 4                        L'Inferno                    Milano Film  1911
# 1      The Story of the Kelly Gang                 J. and N. Tait  1906
# 0                       Miss Jerry     Alexander Black Photoplays  1894
#
# [547 rows x 3 columns]

# %%
newColumn.drop_duplicates()
len(newColumn)
# Out:
# 77651

# %%
newColumn.rename(columns={'avg_vote': 'average_vote'}, inplace=True)
newColumn
# Out:
#                              title  year date_published  \
# 84686          A Wakefield Project  2019     2021-05-07
# 81909              Shadows in Mind  2019     2021-04-30
# 83083                   Winterskin  2018     2021-04-16
# 77295             The Terrible Two  2018     2021-04-02
# 52656                   The Father  2020     2021-01-08
# ...                            ...   ...            ...
# 3                        Cleopatra  1912     1912-11-13
# 9                      Richard III  1912     1912-10-15
# 4                        L'Inferno  1911     1911-03-06
# 1      The Story of the Kelly Gang  1906     1906-12-26
# 0                       Miss Jerry  1894     1894-10-09
#
#                            genre  duration      country language  \
# 84686   Horror, Sci-Fi, Thriller        88  Canada, USA  English
# 81909                   Thriller        92          USA  English
# 83083    Action, Fantasy, Horror        84           UK  English
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(newColumn['average_vote'], bins=20, color='red', edgecolor='black')
plt.title('Histogram of Average Votes')
plt.xlabel('Average Votes')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(newColumn['average_vote'])
plt.title('Boxplot of Average Votes')
plt.ylabel('Average Votes')
plt.show()
