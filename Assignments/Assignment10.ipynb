# %%
import pandas as pd

csv_data = pd.read_csv("part1.csv")
json_data = pd.read_json("part2.json")

print("CSV Data")
csv_data
# Out:
# CSV Data
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
print("JSON Data")
json_data
# Out:
# JSON Data
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
# First 5 Rows of CSV Data

print("First 5 Rows of CSV Data", end="\n")
csv_data.head(5)
# Out:
# First 5 Rows of CSV Data
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Last 3 Rows of CSV Data

print("Last 3 Rows of CSV Data", end="\n")
csv_data.tail(3)
# Out:
# Last 3 Rows of CSV Data
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
# First 5 Rows of the JSON Data

print("First 5 Rows of the JSON Data", end="\n")
json_data.head(5)
# Out:
# First 5 Rows of the JSON Data
#   species_id             genus          species    taxa
# 0         AB        Amphispiza        bilineata    Bird
# 1         AH  Ammospermophilus          harrisi  Rodent
# 2         AS        Ammodramus       savannarum    Bird
# 3         BA           Baiomys          taylori  Rodent
# 4         CB   Campylorhynchus  brunneicapillus    Bird

# %%
# Last 3 Rows of the JSON Data

print("Last 3 Rows of the JSON Data", end="\n")
json_data.tail(3)
# Out:
# Last 3 Rows of the JSON Data
#    species_id        genus     species  taxa
# 51         US      Sparrow         sp.  Bird
# 52         ZL  Zonotrichia  leucophrys  Bird
# 53         ZM      Zenaida    macroura  Bird

# %%
# Combine both data frames into a single one: Columns in the second data frame to the RIGHT of the first data frame

print("Combined both data frames into a single one", end="\n")

combined_dataframe = pd.concat([csv_data, json_data], axis=1)
combined_dataframe
# Out:
# Combined both data frames into a single one
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
# ...

# %%
# Export your results as a CSV and make sure it reads back into Python properly.

combined_dataframe.to_csv('combined_data.csv', index=False)

# %%
# Reading the newly created dataframe

print("Exported the result as a CSV and reading back the newly created CSV file", end="\n")
reading_new_df = pd.read_csv('combined_data.csv')
reading_new_df
# Out:
# Exported the result as a CSV and reading back the newly created CSV file
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# ...

# %%
# Showing the list of columns in your dataframe

print("Showing the list of columns in the dataframe", end="\n")
reading_new_df.columns
# Out:
# Showing the list of columns in the dataframe
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight', 'species_id.1', 'genus', 'species',
#        'taxa'],
#       dtype='object')

# %%
# Do you find any duplicated columns? Display the first 5 rows of your data, is your data accurate?

print("Duplicate Columns", end="\n\n")
duplicate_columns = reading_new_df.columns[reading_new_df.columns.duplicated()]
print("Duplicate Columns: ",duplicate_columns, end="\n\n")

print("First 5 Rows of the data", end="\n\n")
reading_new_df.head()
# Out:
# Duplicate Columns
#
# Duplicate Columns:  Index([], dtype='object')
#
# First 5 Rows of the data
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight species_id.1             genus          species    taxa
# 0     NaN           AB        Amphispiza        bilineata    Bird
# 1     NaN           AH  Ammospermophilus          harrisi  Rodent
# 2     NaN           AS        Ammodramus       savannarum    Bird
# 3     NaN           BA           Baiomys          taylori  Rodent
# 4     NaN           CB   Campylorhynchus  brunneicapillus    Bird

# %%
# Use merge from the pandas package to make an inner join.

print("Doing inner join by using merge", end="\n\n")
merged_dataframe = pd.merge(csv_data, json_data, on='species_id', how='inner')
merged_dataframe
# Out:
# Doing inner join by using merge
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2             22      7   17  1977       15         NL    F             31.0
# 3             38      7   17  1977       17         NL    M             33.0
# 4             72      8   19  1977        2         NL    M             31.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 34781      28988     12   23  1998        6         CT  NaN              NaN
# 34782      35512     12   31  2002       11         US  NaN              NaN
# 34783      35513     12   31  2002       11         US  NaN              NaN
# 34784      35528     12   31  2002       13         US  NaN              NaN
# 34785      35544     12   31  2002       15         US  NaN              NaN
#
# ...

# %%
# Fill the missing value for the column weigh by the mean

print("Filling missing value for the weigh column by mean")
merged_dataframe['weight'] = merged_dataframe['weight'].fillna(merged_dataframe['weight'].mean())
merged_dataframe
# Out:
# Filling missing value for the weigh column by mean
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2             22      7   17  1977       15         NL    F             31.0
# 3             38      7   17  1977       17         NL    M             33.0
# 4             72      8   19  1977        2         NL    M             31.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 34781      28988     12   23  1998        6         CT  NaN              NaN
# 34782      35512     12   31  2002       11         US  NaN              NaN
# 34783      35513     12   31  2002       11         US  NaN              NaN
# 34784      35528     12   31  2002       13         US  NaN              NaN
# ...

# %%
# Plot the distribution of taxa by sex by plot

import matplotlib.pyplot as plt
import seaborn as sb

print("Plot the Distribution of taxa by sex by plot", end="\n\n")
sb.countplot(x='taxa', hue='sex', data=merged_dataframe)
plt.xlabel('Taxa')
plt.ylabel('Count')
plt.title('Distribution of Taxa by Sex')
plt.show()
# Out:
# Plot the Distribution of taxa by sex by plot

# %%
# Plot the distribution of taxa by plot

import matplotlib.pyplot as plt
import seaborn as sb

print("Plot Distribution of taxa by plot", end="\n\n")
plt.figure(figsize=(8,6))
plt.hist(merged_dataframe['taxa'], bins=20)
plt.xlabel('Taxa')
plt.ylabel('Count')
plt.title('Distribution of Taxa')
plt.show()
# Out:
# Plot Distribution of taxa by plot
